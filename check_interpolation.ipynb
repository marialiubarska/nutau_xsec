# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import pickle
import os

# %matplotlib inline

# %%
pth = '/home/mliubar/scratch/jupyter_plots_xsec_q_contrib/xsec/'

# %%
def check_interpolation(filename):
    with open(os.path.join(pth,filename), 'rb') as f:
        genie = pickle.load(f, encoding='latin1')
        
    for k in genie.keys():
        genie[k] = np.array(genie[k])
        
    fig = plt.figure(figsize=(10,8))
    ax = plt.gca()
    ax.set_title(filename)
    ax.set_xlabel('log10(E/GeV)')
    ax.set_ylabel('xsec/E, mbarn/GeV')

    ax.set_xlim(1.,4.)

    for i in range(len(genie['xsec_fits'])):
        ax.plot(np.log10(genie['E_init'][i]), genie['xsec_init'][i]/genie['E_init'][i], 
                '-r')
        ax.plot(np.log10(genie['E_fit']), genie['xsec_fits'][i], '--b')
        
    plt.show()
    
    return 0

# %%
check_interpolation('GENIE_2_12_8_water_splines_highen_fits.pckl')
# Out:
# 0

# %%
check_interpolation('GENIE_3_00_06_water_splines_highen_fits.pckl')
# Out:
# 0

# %%
check_interpolation('GENIE_HEDIS_water_splines_n50_fits.pckl')
# Out:
# 0

# %%
check_interpolation('GENIE_HEDIS_water_splines_CSMS_fits.pckl')
# Out:
# 0

# %%
check_interpolation('GENIE_HEDIS_water_splines_KM3NET_fits.pckl')
# Out:
# 0
